# %% [markdown]
# <a href="https://colab.research.google.com/github/jyoshitha1198/python/blob/main/matplotib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 100])
ypoints = np.array([0, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["tel", "hin", "eng", "math"])
y = np.array([25, 24, 29, 30])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10,23])

plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["tel", "hin", "eng", "math"])
y = np.array([25, 24, 29, 30])

plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
a=["tel","hin","eng","math"]

plt.pie(y,labels=a)
plt.show()
